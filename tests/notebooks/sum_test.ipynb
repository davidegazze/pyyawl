# %%
a = 2
b = 3
image_path = './imgs/image_1.jpg'

# %%
# !pip install pillow

# %%
from PIL import Image

# %%
def sum_func(x,y):
    return x + y

# %%
print('called', sum_func(a,b))
# Out:
# called 5

# %%
Image.open(image_path)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x480 at 0x7FAB4F366DF0>
